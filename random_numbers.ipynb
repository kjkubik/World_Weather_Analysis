# %%
# Import the random module
import random

# %%
random.randint(-90,90)
# Out:
# -39

# %%
random.random()
# Out:
# 0.7971012529817411

# %%
x = 1
latitudes = []
while x < 11:
    random_lat = random.randint(-90, 89) + random.random()
    latitudes.append(random_lat)
    x += 1
print(latitudes)
# Out:
# [-49.167033105838144, -44.19927017585966, -9.753669332942387, 3.646032463932055, 1.4306392833591888, 64.888767653898, -24.527173523575385, 59.86064154250207, -22.683242923456074, -17.979459223141564]

# %%
random.randrange(-90, 90, step=3)
# Out:
# -12

# %%
random.uniform(-90, 90)
# Out:
# 64.96556082638097

# %%
# Import the NumPy module.
import numpy as np

# %%
np.random.uniform(-90.000, 90.000)
# Out:
# -0.47858825435602625

# %%
np.random.uniform(-90, 90)
# Out:
# 55.66311407563708

# %%
np.random.uniform(-90.000, 90.000, size=50)
# Out:
# array([ 85.98593707, -76.56196435, -68.8101994 ,  -2.44972058,
#        -74.68298492, -50.04018949,  60.16433419, -56.44782319,
#        -27.71632676, -79.03307053,   5.95690148,   9.10156939,
#        -34.42592484,  21.48869062,  51.75812699, -27.5943515 ,
#         78.01863221,  -9.73832485, -52.42293101, -82.53570287,
#        -59.7071571 , -48.09833556,  37.91127228,  66.62736489,
#         39.36190512,  61.89882316,  76.61463295,  42.04936664,
#         50.60292562,  10.96073974,  37.4862755 , -63.80687433,
#         13.56582823,  52.92836048, -75.49567678,  53.52268769,
#          6.45382024,  41.71558267,  79.79649997, -31.67588847,
#         60.72876589, -39.68299264,  36.28748909,  19.11378732,
#        -86.286196  , -45.01144597, -65.33983761, -24.9645983 ,
#         -9.78438719,  89.06327303])

# %%
# Import timeit.
import timeit
# %timeit np.random.uniform(-90.000, 90.000, size=1500)
# Out:
# 9.87 µs ± 220 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
def latitudes(size):
    latitudes = []
    x = 0
    while x < (size):
        random_lat = random.randint(-90, 90) + random.random()
        latitudes.append(random_lat)
        x += 1
    return latitudes
# Call the function with 1500.
# %timeit latitudes(1500)
# Out:
# 1.26 ms ± 15.6 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
def latitudes(size):
    latitudes = []
    x = 0
    for x in range(size): 
        random_lat = random.randint(-90, 90) + random.random()
        latitudes.append(random_lat)
        x += 1
    return latitudes
# Call the function with 1500.
# %timeit latitudes(1500)
# Out:
# 1.25 ms ± 11.7 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
